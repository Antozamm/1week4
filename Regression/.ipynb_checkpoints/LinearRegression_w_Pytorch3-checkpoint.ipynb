# %% [markdown]
# ## Regressione lineare con Pytorch

# %% [markdown]
# In questo articolo voglio implementare una regressione lineare con Pytorch.

# %% [markdown]
# Iniziamo con l'inquadrare il problema.

# %% [markdown]
# Ho N variabili di ingresso $x_1,x_2,\dots,x_N$ ed 1 uscita $y$.<br>
# Il modello che voglio usare è quello della regressione lineare così definito:
# \begin{equation*}
# y = \theta_0 + \theta_1 x_1 + \theta_2 x_2 + ... + \theta_N x_N = \Theta \cdot X^T
# \end{equation*}
# con:
# \begin{equation*}
# \Theta =
# \begin{bmatrix}
# \theta_0  & \theta_1  & \dots & \theta_N
# \end{bmatrix}
# \end{equation*}
# \begin{equation*}
# X =
# \begin{bmatrix}
# x_0  & x_1  & \dots & x_N
# \end{bmatrix}
# \end{equation*}
# \begin{equation*}
# x_0 = 1
# \end{equation*}

# %% [markdown]
# Quindi devo trovare i parametri $\theta_0,\theta_1,\dots,\theta_N$ tali che l'errore $loss(y_{modello}, y_{target})$ sia il minimo.

# %% [markdown]
# ### Il modello lineare

# %% [markdown]
# Importiamo i package necessari:

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Definiamo un modello di regressione lineare con 10 ingressi e 1 uscita, ci serviamo della funzione di PyTorch <strong>torch.nn.Linear()</strong>:

# %%
model = nn.Linear(10,1)

# %% [markdown]
# i cui parametri sono i pesi (weight) e il bias, in tutto 11 parametri da ottimizzare:

# %%
model.weight, model.bias
# Out:
# (Parameter containing:
#  tensor([[-0.1864, -0.0766, -0.1334, -0.1834,  0.1137, -0.0490, -0.1517, -0.0004,
#            0.0095, -0.2024]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.2126], requires_grad=True))

# %% [markdown]
# Definendo un tensore di ingresso con dimensioni 1x10

# %%
x = torch.randn(1,10)

# %% [markdown]
# L'uscita del modello è:

# %%
y1 = model(x)
y1
# Out:
# tensor([[-0.0237]], grad_fn=<AddmmBackward>)

# %% [markdown]
# ### Modello lineare, ingresso singolo e training del modello

# %% [markdown]
# Facciamo il primo esempio più semplice con un solo ingresso e una sola uscita.

# %% [markdown]
# Creiamo un set di dati, costituito da N coppie (x,y), che stanno in una relazione "abbastanza" lineare tra di loro.<br>
# Per fare questo definiamo una relazione lineare tra y e x. E aggiungiamo un rumore per rendere la cosa più realistica.

# %%
x_samples = torch.linspace(0, 1000, steps=10001).view(-1,1) #l'ingresso deve essere in formato colonna
m = 13.5 #coefficiente angolare
b = 12 #ordinata all'origine
y_samples_lineare = m * x_samples + b

# %%
y_samples_lineare.size()
# Out:
# torch.Size([10001, 1])

# %%
y_samples_noise = 200 * torch.randn(x_samples.shape[0], 1) #genera un vettore colonna di dati random, con media 0 e varianza 5 
y_samples_noise.size()
# Out:
# torch.Size([10001, 1])

# %% [markdown]
# Abbiamo già visto che i vettori y_samples_lineare e y_samples_noise hanno le stesse dimensioni. Possiamo pertanto sommarli:

# %%
y_samples = y_samples_lineare + y_samples_noise

# %% [markdown]
# (x_samples, y_samples) è il dataset di punti che devo interpolare (o fittare).

# %% [markdown]
# Instanzio il modello lineare con un ingresso e una uscita. Il parametro bias=True indica che devo ottimizare il bias (ordinata all'origine) del modello.

# %%
model1 = torch.nn.Linear(1,1, bias=True)

# %% [markdown]
# Il modello ha solo due parametri da ottimizzare, che in accordo alla letteratura classica chiameremo $m$ e $q$:

# %%
model1.weight, model1.bias
# Out:
# (Parameter containing:
#  tensor([[-0.1526]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.6956], requires_grad=True))

# %% [markdown]
# Calcolo le uscite del modello lineare appena definito:

# %%
y_linmod = model1(x_samples)
y_linmod.size()
# Out:
# torch.Size([10001, 1])

# %% [markdown]
# Mettiamo su grafico le due curve (x_samples, y_samples) e (x_samples, y_linmod).<br>
# Come si vede il modello lineare non è stato adattato. Pertanto la linea rossa devia nettamente dalla nuvola di punti blu.

# %%
ax = plt.figure(figsize = (12,8))
plt.scatter(x_samples.numpy(),y_samples.numpy(), label="dataset")
plt.plot(x_samples.numpy(),y_linmod.detach().numpy(),'r', label="linear model")
plt.legend()
plt.show()

# %% [markdown]
# Calcolo l'errore quadratico medio tra il dataset e il valore corrente dell'uscita. Per qualche motivo la funzione predefinita di PyTorch <strong>nn.MSELoss()</strong> mi da errore, pertanto definisco l'errore quadratico medio esplicitamente.

# %%
# errore = nn.MSELoss(y_linmod, y_linmod)
errore = torch.mean(torch.pow(y_samples-y_linmod, 2))
errore
# Out:
# tensor(62318424., grad_fn=<MeanBackward0>)

# %% [markdown]
# Calcolo le derivate parziali dell'errore rispetto ai due parametri m e q, usando la funzione backward().

# %%
errore.backward()

# %% [markdown]
# Come ottimizzatore uso lo SGD (Stochastic Gradient Descent):

# %%
optimizer = torch.optim.SGD(model1.parameters(),1e-6)

# %% [markdown]
# Itero su un numero basso di iterazioni, poiché la convergenza è veloce.

# %%
for i in range(100):
    y_linmod = model1(x_samples)
    errore = torch.mean(torch.pow(y_samples-y_linmod, 2))
    errore.backward()
    optimizer.step()
    optimizer.zero_grad()
    print(errore)
    ax = plt.figure(figsize = (12,8))
    plt.scatter(x_samples.numpy(),y_samples.numpy(), label="dataset")
    plt.plot(x_samples.numpy(),y_linmod.detach().numpy(),'r', label="linear model")
    plt.legend()
    plt.show()
# Out:
# tensor(62318424., grad_fn=<MeanBackward0>)
# tensor(6963052.5000, grad_fn=<MeanBackward0>)
# tensor(809406.7500, grad_fn=<MeanBackward0>)
# tensor(125810.2891, grad_fn=<MeanBackward0>)
# tensor(49870.5000, grad_fn=<MeanBackward0>)
# tensor(41434.5898, grad_fn=<MeanBackward0>)
# tensor(40497.4453, grad_fn=<MeanBackward0>)
# tensor(40393.3477, grad_fn=<MeanBackward0>)
# tensor(40381.7812, grad_fn=<MeanBackward0>)
# tensor(40380.4961, grad_fn=<MeanBackward0>)
# tensor(40380.3516, grad_fn=<MeanBackward0>)
# tensor(40380.3359, grad_fn=<MeanBackward0>)
# tensor(40380.3359, grad_fn=<MeanBackward0>)
# tensor(40380.3398, grad_fn=<MeanBackward0>)
# tensor(40380.3359, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3359, grad_fn=<MeanBackward0>)
# tensor(40380.3359, grad_fn=<MeanBackward0>)
# tensor(40380.3359, grad_fn=<MeanBackward0>)
# tensor(40380.3359, grad_fn=<MeanBackward0>)
# tensor(40380.3359, grad_fn=<MeanBackward0>)
# tensor(40380.3359, grad_fn=<MeanBackward0>)
# tensor(40380.3359, grad_fn=<MeanBackward0>)
# tensor(40380.3359, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3359, grad_fn=<MeanBackward0>)
# tensor(40380.3359, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3320, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)
# tensor(40380.3281, grad_fn=<MeanBackward0>)

# %% [markdown]
# Come si vede dai grafici sopra la convergenza è velocissima, già alla seconda iterazione la linea rossa si attesta sulla nuvola blu.<br>
# Un altro paio di iterazioni e il fitting è ottimale.

# %% [markdown]
# I parametri ottimizzati sono:

# %%
list(model1.parameters())
# Out:
# [Parameter containing:
#  tensor([[13.5157]], requires_grad=True),
#  Parameter containing:
#  tensor([-0.6741], requires_grad=True)]

# %% [markdown]
# Come si vede il model.weight è molto vicino al valore di $m = 13.5$ che avevamo usato per generare il dataset.<br>
# Il valore di q invece si discosta abbastanza, 12 contro -0.2154<br>
# Qualche <strong>ipotesi</strong> sul perché di questa discrepanza?

# %% [markdown]
# ## Neural Net

# %%
class MyNetworkClass(nn.Module):
    
    def __init__ (self, depth_layers, dim_hidden_layer, learning_rate):
        
        super(MyNetworkClass, self).__init__()
        
        self.par = (depth_layers, dim_hidden_layer, learning_rate)
        
        if depth_layers==1:
            dim_hidden_layer = 1 #corregge dim_hidden_layer
        
        self.model = nn.Sequential( #layers di ingresso
            nn.Linear(in_features=1, out_features=dim_hidden_layer, bias=True), 
            nn.ReLU(),    
        )

        
        if depth_layers > 2: #layers intermedi
            for i in range(depth_layers-1):
                self.model.add_module('lin_lay_'+str(i),nn.Linear(dim_hidden_layer,dim_hidden_layer))
                self.model.add_module('rel_lay_'+str(i),nn.ReLU())
        
        if depth_layers > 1: #layers di uscita
            self.model.add_module('lin_lay_'+str(depth_layers),nn.Linear(dim_hidden_layer,1))
            self.model.add_module('rel_lay_'+str(depth_layers),nn.ReLU())
        
        self.loss_fn = nn.MSELoss(reduction='mean')
        
        self.opt = torch.optim.SGD(self.model.parameters(), lr=learning_rate)
    
    def forward(self,x):
        
        y_pred = self.model(x)
        return y_pred
    
    def fit(self, x, y, reset=True):
        
        
        y_pred = self.model(x)
        loss = self.loss_fn(y_pred, y)
        loss.backward()              #calcola i gradienti
        
        self.opt.step()              #aggiorna i parametri
        self.opt.zero_grad()         #azzera i gradienti
        
        #calculate error
        #backprop
        
        print(loss.data)
        return(loss.data)
    
    def data_batch(self, x, y, batch_size):
        
        train = torch.utils.data.TensorDataset(x, y)
        train_loader = torch.utils.data.DataLoader(
            train, batch_size=self.batch_size, shuffle=self.shuffle
        )
        return train_loader
    
    def epoch_fit(self, batch_size, x, y, reset=True):
        
        self.batch_size = batch_size
        self.shuffle = True
        
        train_loader = self.data_batch(x, y, batch_size)
        
        for i in range(len(train_loader)):
            xbatch,ybatch = next(iter(train_loader))
            y_pred = self.model(xbatch)
            loss = self.loss_fn(y_pred, ybatch)
            loss.backward()              #calcola i gradienti

            self.opt.step()              #aggiorna i parametri
            self.opt.zero_grad()         #azzera i gradienti
        
        #calculate error
        #backprop
        
        print(loss.data)
        return(loss.data)

# %%
mynn = MyNetworkClass(depth_layers=2, dim_hidden_layer=24, learning_rate=1e-8)

# %%
print(mynn)
# Out:
# MyNetworkClass(
#   (model): Sequential(
#     (0): Linear(in_features=1, out_features=24, bias=True)
#     (1): ReLU()
#     (lin_lay_2): Linear(in_features=24, out_features=1, bias=True)
#     (rel_lay_2): ReLU()
#   )
#   (loss_fn): MSELoss()
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

num_par = count_parameters(mynn)
num_par
# Out:
# 73

# %%
step = 1000
err_in = float(mynn.fit(x_samples, y_samples).numpy())
for i in range(step):
    mynn.fit(x_samples, y_samples)
err_fin = float(mynn.fit(x_samples, y_samples).numpy())
# Out:
# tensor(59353652.)
# tensor(57293568.)
# tensor(55227524.)
# tensor(53103508.)
# tensor(50878636.)
# tensor(48518668.)
# tensor(45998368.)
# tensor(43302532.)
# tensor(40427372.)
# tensor(37381976.)
# tensor(34189492.)
# tensor(30887462.)
# tensor(27526948.)
# tensor(24170106.)
# tensor(20886010.)
# tensor(17745122.)
# tensor(14812945.)
# tensor(12143925.)
# tensor(9776603.)
# tensor(7730974.)
# tensor(6008347.)
# tensor(4593612.)
# tensor(3459180.2500)
# tensor(2569685.7500)
# tensor(1886533.)
# tensor(1371639.8750)
# tensor(990061.8125)
# tensor(711478.3125)
# tensor(510735.6875)
# tensor(367716.6250)
# tensor(266812.1562)
# tensor(196210.8750)
# tensor(147159.3906)
# tensor(113281.9609)
# tensor(90000.6016)
# tensor(74067.7344)
# tensor(63201.5664)
# tensor(55812.0781)
# tensor(50798.9141)
# tensor(47404.5508)
# tensor(45110.0312)
# tensor(43560.9961)
# tensor(42516.4414)
# tensor(41812.6875)
# tensor(41338.9141)
# tensor(41020.1367)
# tensor(40805.7656)
# tensor(40661.6602)
# tensor(40564.8320)
# tensor(40499.7891)
# tensor(40456.1055)
# tensor(40426.7578)
# tensor(40407.0586)
# tensor(40393.8359)
# tensor(40384.9609)
# tensor(40378.9961)
# tensor(40375.0039)
# tensor(40372.3203)
# tensor(40370.5156)
# tensor(40369.3086)
# tensor(40368.4961)
# tensor(40367.9570)
# tensor(40367.5938)
# tensor(40367.3438)
# tensor(40367.1797)
# tensor(40367.0742)
# tensor(40366.9961)
# tensor(40366.9492)
# tensor(40366.9141)
# tensor(40366.8867)
# tensor(40366.8750)
# tensor(40366.8672)
# tensor(40366.8633)
# tensor(40366.8555)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8477)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8516)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8516)
# tensor(40366.8477)
# tensor(40366.8516)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8516)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8516)
# tensor(40366.8477)
# tensor(40366.8516)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8438)
# tensor(40366.8516)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8516)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8516)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8516)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8516)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8438)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8477)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8516)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8516)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8516)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8516)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8516)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8516)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8516)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8516)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8477)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8477)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8359)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8320)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8320)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8320)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8320)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8438)
# tensor(40366.8438)
# tensor(40366.8359)
# tensor(40366.8320)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8320)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8320)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8320)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8320)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8320)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8320)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8359)
# tensor(40366.8398)
# tensor(40366.8398)
# tensor(40366.8398)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-1dd1894d4575> in <module>
#       2 err_in = float(mynn.fit(x_samples, y_samples).numpy())
#       3 for i in range(step):
# ----> 4     mynn.fit(x_samples, y_samples)
#       5 err_fin = float(mynn.fit(x_samples, y_samples).numpy())
#
# <ipython-input-76-9100ed99c879> in fit(self, x, y, reset)
#      39         y_pred = self.model(x)
#      40         loss = self.loss_fn(y_pred, y)
# ---> 41         loss.backward()              #calcola i gradienti
#      42
#      43         self.opt.step()              #aggiorna i parametri
#
# ~\Anaconda3\envs\conda2020\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~\Anaconda3\envs\conda2020\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#     134
#
# KeyboardInterrupt:

# %%
step = 1000
err_in = float(mynn.fit(x_samples, y_samples).numpy())
for i in range(step):
    mynn.epoch_fit(64,x_samples, y_samples)
err_fin = float(mynn.fit(x_samples, y_samples).numpy())
# Out:
# tensor(40366.8398)
# ---------------------------------------------------------------------------
# ModuleAttributeError                      Traceback (most recent call last)
# <ipython-input-81-769f835df488> in <module>
#       2 err_in = float(mynn.fit(x_samples, y_samples).numpy())
#       3 for i in range(step):
# ----> 4     mynn.epoch_fit(64,x_samples, y_samples)
#       5 err_fin = float(mynn.fit(x_samples, y_samples).numpy())
#
# <ipython-input-76-9100ed99c879> in epoch_fit(self, batch_size, x, y, reset)
#      62         self.batch_size = batch_size
#      63
# ---> 64         train_loader = self.data_batch(x, y, batch_size)
#      65
#      66         for i in range(len(train_loader)):
#
# <ipython-input-76-9100ed99c879> in data_batch(self, x, y, batch_size)
#      54         train = torch.utils.data.TensorDataset(x, y)
#      55         train_loader = torch.utils.data.DataLoader(
# ---> 56             train, batch_size=self.batch_size, shuffle=self.shuffle
#      57         )
#      58         return train_loader
#
# ~\Anaconda3\envs\conda2020\lib\site-packages\torch\nn\modules\module.py in __getattr__(self, name)
#     777                 return modules[name]
#     778         raise ModuleAttributeError("'{}' object has no attribute '{}'".format(
# --> 779             type(self).__name__, name))
#     780
#     781     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# ModuleAttributeError: 'MyNetworkClass' object has no attribute 'shuffle'

# %%
results = pd.DataFrame(columns=('depth','dim','lr','num_par','batch','step','err_in','err_fin'))
results
# Out:
# Empty DataFrame
# Columns: [depth, dim, lr, num_par, batch, step, err_in, err_fin]
# Index: []

# %%
if np.isnan(results.index.max()):
    results.loc[0,results.columns[0:3]] = mynn.par
    results.loc[0,results.columns[3]] = num_par
    results.loc[0,results.columns[4]] = batch
    results.loc[0,results.columns[5]] = step
    results.loc[0,results.columns[6]] = err_in
    results.loc[0,results.columns[7]] = err_fin
else:
    ultimo_idx = results.index[-1]+1
    results.loc[ultimo_idx,results.columns[0:3]] = mynn.par
    results.loc[ultimo_idx,results.columns[3]] = num_par
    results.loc[ultimo_idx,results.columns[4]] = batch
    results.loc[ultimo_idx,results.columns[5]] = step
    results.loc[ultimo_idx,results.columns[6]] = err_in
    results.loc[ultimo_idx,results.columns[7]] = err_fin
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-4f615b1c1973> in <module>
#       2     results.loc[0,results.columns[0:3]] = mynn.par
#       3     results.loc[0,results.columns[3]] = num_par
# ----> 4     results.loc[0,results.columns[4]] = batch
#       5     results.loc[0,results.columns[5]] = step
#       6     results.loc[0,results.columns[6]] = err_in
#
# NameError: name 'batch' is not defined

# %%
y_nn_pred = mynn.forward(x_samples)
y_nn_pred

# %%
ax = plt.figure(figsize = (12,8))
plt.scatter(x_samples.numpy(),y_samples.numpy(), label="dataset")
plt.plot(x_samples.numpy(),y_nn_pred.detach().numpy(),'r', label="linear model")
plt.legend()
plt.show()

# %%
for par in mynn.parameters():
    print(par)

# %%
np.var(y_samples.numpy())

# %%
train = torch.utils.data.TensorDataset(x_samples, y_samples)

train_loader = torch.utils.data.DataLoader(
    train, batch_size=10, shuffle=True
)

# %%
for batch_ndx, sample in enumerate(train_loader):
    print(batch_ndx, len(sample), sample[0].shape)
# Out:
# 0 2 torch.Size([10, 1])
# 1 2 torch.Size([10, 1])
# 2 2 torch.Size([10, 1])
# 3 2 torch.Size([10, 1])
# 4 2 torch.Size([10, 1])
# 5 2 torch.Size([10, 1])
# 6 2 torch.Size([10, 1])
# 7 2 torch.Size([10, 1])
# 8 2 torch.Size([10, 1])
# 9 2 torch.Size([10, 1])
# 10 2 torch.Size([10, 1])
# 11 2 torch.Size([10, 1])
# 12 2 torch.Size([10, 1])
# 13 2 torch.Size([10, 1])
# 941 2 torch.Size([10, 1])
# 942 2 torch.Size([10, 1])
# 943 2 torch.Size([10, 1])
# 944 2 torch.Size([10, 1])
# 945 2 torch.Size([10, 1])
# 946 2 torch.Size([10, 1])
# 947 2 torch.Size([10, 1])
# 948 2 torch.Size([10, 1])
# 949 2 torch.Size([10, 1])
# 950 2 torch.Size([10, 1])
# 951 2 torch.Size([10, 1])
# 952 2 torch.Size([10, 1])
# 953 2 torch.Size([10, 1])
# 954 2 torch.Size([10, 1])
# 955 2 torch.Size([10, 1])
# 956 2 torch.Size([10, 1])
# 957 2 torch.Size([10, 1])
# 958 2 torch.Size([10, 1])
# 959 2 torch.Size([10, 1])
# 960 2 torch.Size([10, 1])
# 961 2 torch.Size([10, 1])
# 962 2 torch.Size([10, 1])
# 963 2 torch.Size([10, 1])
# 964 2 torch.Size([10, 1])
# 965 2 torch.Size([10, 1])
# 966 2 torch.Size([10, 1])
# 967 2 torch.Size([10, 1])
# 968 2 torch.Size([10, 1])
# 969 2 torch.Size([10, 1])
# 970 2 torch.Size([10, 1])
# 971 2 torch.Size([10, 1])
# 972 2 torch.Size([10, 1])
# 973 2 torch.Size([10, 1])
# 974 2 torch.Size([10, 1])
# 975 2 torch.Size([10, 1])
# 976 2 torch.Size([10, 1])
# 977 2 torch.Size([10, 1])
# 978 2 torch.Size([10, 1])
# 979 2 torch.Size([10, 1])
# 980 2 torch.Size([10, 1])
# 981 2 torch.Size([10, 1])
# 982 2 torch.Size([10, 1])
# 983 2 torch.Size([10, 1])
# 984 2 torch.Size([10, 1])
# 985 2 torch.Size([10, 1])
# 986 2 torch.Size([10, 1])
# 987 2 torch.Size([10, 1])
# 988 2 torch.Size([10, 1])
# 989 2 torch.Size([10, 1])
# 990 2 torch.Size([10, 1])
# 991 2 torch.Size([10, 1])
# 992 2 torch.Size([10, 1])
# 993 2 torch.Size([10, 1])
# 994 2 torch.Size([10, 1])
# 995 2 torch.Size([10, 1])
# 996 2 torch.Size([10, 1])
# 997 2 torch.Size([10, 1])
# 998 2 torch.Size([10, 1])
# 999 2 torch.Size([10, 1])
# 1000 2 torch.Size([1, 1])

# %%
x,y = next(iter(train_loader))

# %%
x
# Out:
# tensor([[854.8000],
#         [734.1000],
#         [462.8000],
#         [159.9000],
#         [164.6000],
#         [571.0000],
#         [187.5000],
#         [ 44.8000],
#         [ 86.8000],
#         [ 81.8000]])

# %%
y
# Out:
# tensor([[ 4862.5171],
#         [ 4313.1587],
#         [ 4759.4424],
#         [12971.6904],
#         [ 2568.3359],
#         [ 7960.7466],
#         [ 9428.4180],
#         [12652.5293],
#         [ 5844.8071],
#         [ 7735.8350]])

# %%
def gen_():
    if self.batches_per_epoch is None:
        while True:
            yield from enumerate(train_loader)
            yield None
    else:
        iidx = 0
        it = itertools.chain.from_iterable(iter(lambda:enumerate(train_loader), None))
        while True:
            yield next(it)
            iidx += 1
            if not idx % self.batches_per_epoch:
                yield None

train_batches = gen_()

# %%
train_batches
# Out:
# <generator object gen_ at 0x00000172ABE4B0C8>

# %% [markdown]
# ### Modello di regressione lineare multidimensionale

# %% [markdown]
# Facciamo un esempio con più variabili di ingresso. 4 ingressi per essere precisi.
# Questi sono gli step:
# - genero un dataset
# - creo il modello di regressione lineare
# - definisco una funzione errore e un ottimizzatore
# - faccio il training del modello

# %% [markdown]
# #### Genero un dataset

# %% [markdown]
# Creo un dataset di 1000 punti $(x_1,x_2,x_3,x_4,y)$. <br>
# Per i dati di ingresso uso la funzione torch.linspace. <br>
# I dati di uscita sono una combinazione lineare degli ingressi, i coefficienti $m_i$ sono stati scelti in modo che ogni ingresso contribuisca sull'uscita.

# %%
#x1 = torch.linspace(0,100,100).view(-1,1)
#x2 = torch.linspace(-1,1,100).view(-1,1)
#x3 = torch.linspace(-10,0,100).view(-1,1)
#x4 = torch.linspace(75,150,100).view(-1,1)
x1 = np.linspace(0,100,50)
x2 = np.linspace(-1,1,50)
x3 = np.linspace(-10,0,50)
x4 = np.linspace(75,150,50)

m1, m2, m3, m4 = 0.5, 25, 50, -0.66 #coeff angolare per ogni direzione
M = torch.tensor([m1,m2,m3,m4]).view([-1,1]) #combino i coeff angolari in un vettore colonna

# X = torch.from_numpy(x_comb).type(torch.float) # setto float altrimenti si setta automaticamente double e da errore


# y_samples = m1 * x1 + m2 * x2 + m3 * x3 + m4 * x4 
# y_samples = torch.from_numpy(y_samples).type(torch.float)

# %% [markdown]
# Genero uno spazio a 4 dimensioni, usando le coordinate x1,x2,x3,x4:

# %%
x_comb = np.array([[x1[i],x2[j],x3[l],x4[m]] 
      for i in range(x1.shape[0]) 
      for j in range(x2.shape[0]) 
      for l in range(x3.shape[0]) 
      for m in range(x4.shape[0])])

x_comb.shape
# Out:
# (6250000, 4)

# %%
x_comb
# Out:
# array([[  0.        ,  -1.        , -10.        ,  75.        ],
#        [  0.        ,  -1.        , -10.        ,  76.53061224],
#        [  0.        ,  -1.        , -10.        ,  78.06122449],
#        ...,
#        [100.        ,   1.        ,   0.        , 146.93877551],
#        [100.        ,   1.        ,   0.        , 148.46938776],
#        [100.        ,   1.        ,   0.        , 150.        ]])

# %% [markdown]
# Converto x_comb in un tensore e setto il tipo su flot(=float32), poichè il tipo double(=float64) genera un errore:

# %%
X = torch.from_numpy(x_comb).type(torch.float)

# %% [markdown]
# Calcolo l'uscita del modello lineare:

# %%
y_samples = torch.mm(X,M)
y_samples.shape
# Out:
# torch.Size([6250000, 1])

# %% [markdown]
# Così ho completato la geneerazione del set di dati (x_samples, y_samples)

# %% [markdown]
# #### Creazione modello Lineare

# %% [markdown]
# Definiamo il modello:

# %%
model2 = torch.nn.Linear(4,1)

# %% [markdown]
# Questi sono i parametri, inizializzati in maniera random:

# %%
model2.weight, model2.bias
# Out:
# (Parameter containing:
#  tensor([[-0.4316, -0.4871, -0.4270, -0.2966]], requires_grad=True),
#  Parameter containing:
#  tensor([0.4618], requires_grad=True))

# %% [markdown]
# I dati di input li abbiamo definiti in precedenza, verifichiamo il tipo del tensore X:

# %%
X.type()
# Out:
# 'torch.FloatTensor'

# %% [markdown]
# Calcolo l'uscita del modello lineare, e verifico che lo shape dell'uscita si giusta.<br>
# 1000 punti di ingresso, ne generano altrettanti in uscita, pertanto è corretto.

# %%
y_linmod = model2(X)
y_linmod.shape
# Out:
# torch.Size([6250000, 1])

# %% [markdown]
# L'errore quadratico medio è:

# %%
errore = torch.mean(torch.pow(y_samples-y_linmod,2))
errore
# Out:
# tensor(84055.8906, grad_fn=<MeanBackward1>)

# %% [markdown]
# Plottiamo le uscite generate e confrontiamole con quelle del dataset.<br>
# Sull'asse x metto l'ordinale del punto.

# %%
asse_x = np.linspace(0, X.shape[0]-1, num=X.shape[0])

# %%
def downsample_4_plot(asse_x, downsample_factor):
    asse_x_dwnsmpl = asse_x[0:-1:downsample_factor]
    return asse_x_dwnsmpl

# %%
downsample_factor = 25000
asse_x_dwnsmpl = downsample_4_plot(asse_x,downsample_factor)
y_samples_dwnsmpl = downsample_4_plot(y_samples, downsample_factor)
y_linmod_dwnsmpl = downsample_4_plot(y_linmod, downsample_factor)
asse_x_dwnsmpl.shape
# Out:
# (250,)

# %%
y_linmod_dwnsmpl = downsample_4_plot(y_linmod, downsample_factor)
y_linmod_dwnsmpl.shape
# Out:
# torch.Size([250, 1])

# %%
asse_x.shape, X.shape, y_samples.shape, y_linmod.shape
# Out:
# ((6250000,),
#  torch.Size([6250000, 4]),
#  torch.Size([6250000, 1]),
#  torch.Size([6250000, 1]))

# %%
asse_x[0:-1:downsample_factor].shape
# Out:
# (250,)

# %%
downsample_factor
# Out:
# 25000

# %%
ax = plt.figure(figsize = (12,8))
plt.plot(asse_x,y_samples.detach().numpy())
plt.show()

# %%
y_samples.numpy()[0:200000:downsample_factor]
# Out:
# array([[-574.5    ],
#        [-564.2959 ],
#        [-554.09186],
#        [-543.88776],
#        [-533.6837 ],
#        [-573.4796 ],
#        [-563.2755 ],
#        [-553.0715 ]], dtype=float32)

# %%
y_linmod.detach().numpy()[0:-1:downsample_factor].shape
# Out:
# (250, 1)

# %%
ax = plt.figure(figsize = (12,8))
plt.scatter(asse_x[0:-1:downsample_factor],y_samples.numpy()[0:-1:downsample_factor], label="dataset")
plt.scatter(asse_x[0:-1:downsample_factor],y_linmod.detach().numpy()[0:-1:downsample_factor],c='r', label="linear model")
plt.legend()
plt.show()

# %% [markdown]
# Definiamo il SGD come ottimizzatore, indichiamo che i parametri di ottimizzazione sono quelli di model2, e gli diamo un passo di apprendimento abbastanza piccolo da essere sicuri che converga, ma senza essere troppo lenti, dopo qualche iterazione sono arrivato a 5e-5:

# %%
model2 = torch.nn.Linear(4,1) #ridefinisco il modello per azzerare i calcoli precedenti
optimizer = torch.optim.SGD(model2.parameters(), 5e-5)

# %% [markdown]
# Adesso sono pronto ad eseguire il training del modello.<br>
# I passi sono i soliti:<br>
# -calcolo dell'uscita<br>
# -calcolo dell'errore<br>
# -calcolo del gradiente (errore.backward)<br>
# -aggionamento dei parametri (optimizer.step)<br>
# -reset del gradiente (optimizer.zero_grad)

# %%
for itr in range(501):
    y_linmod = model2(X)   #calcolo l'uscita con il modello corrente
    errore = torch.mean(torch.pow(y_samples-y_linmod,2)) #calcolo l'errore tra l'uscita desiderata e l'uscita corrente
    errore.backward()      #applico la funzione backward, le derivate parziali dell'errore vengono calcolate rispetto alle variabili per cui è definito required_grad=True
    optimizer.step()       #aggiornamento dei parametri da ottimizzare usando le derivate calcolate nel passo precedente
    optimizer.zero_grad()  #azzero i gradienti
    if ((itr==0) or (itr==100) or (itr==200) or (itr==300) or (itr==400) or (itr==500)) : #genera il grafico agli step fissati 
        ax = plt.figure(figsize = (12,8))
        plt.scatter(downsample_4_plot(asse_x,downsample_factor),
                    downsample_4_plot(y_samples, downsample_factor).numpy(),
                    label="dataset", c='g', s=200)
        plt.scatter(downsample_4_plot(asse_x,downsample_factor),
                    downsample_4_plot(y_linmod, downsample_factor).detach().numpy().reshape(1,-1),
                    c='r', label="linear model",s=10)
        plt.legend()
        plt.title('Dopo %d iterazioni - Errore= %1.2f' %(itr,errore))
        plt.show()

# %% [markdown]
# Come si vede dopo 500 iterazioni l'errore è abbastanza alto e la convergenza abbastanza lenta.<br>

# %% [markdown]
# Se provo ad alzare il learning rate, l'errore inizia a divergere, per cui non è una strada praticabile.<br>
# La domanda che mi pongo è: come mai con un learning rate così basso (5e-5) la convergenza è così critica che basta alzare il learning rate di poco (per esempio 1e-4) perché la convergenga sia compromessa.<br>
# La risposta che riesco a darmi è che gli ordini di grandezza delle variabili d'ingresso sono diversi, per cui lo spostamento del punto (dipendente dal learning rate e dal gradiente) deve essere compatibile con tutte le variabili, pertanto deve essere piccolo.<br>
# Vediamo se riesco a velocizzare la convergenza <strong>normalizzando</strong> le variabili $x_1, x_2, x_3, x_4$.

# %% [markdown]
# Normalizziamo le coordinate.

# %%
X.shape
# Out:
# torch.Size([6250000, 4])

# %%
m[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-484aa8232cb2> in <module>
# ----> 1 m[0]
#
# TypeError: 'float' object is not subscriptable

# %%
m = X.min(dim=0)               #valore minimo per ogni colonna di X
M = X.max(dim=0)               #valore massimo per ogni colonna
u = (M[0]+m[0])/2              #valor medio per ogni colonna
d = (M[0]-m[0]).view([1,-1])   #intervallo min-max, per ogni colonna

# %% [markdown]
# m = X.min(dim=0)                     #valore minimo per ogni colonna di X
# M = X.max(dim=0)                     #valore massimo per ogni colonna
# u = (M.values+m.values)/2            #valor medio per ogni colonna
# d = (M.values-m.values).view([1,-1]) #intervallo min-max, per ogni colonna

# %% [markdown]
# Ad ogni coordinata sottraggo il suo valor medio e divido per l'intervallo di variazione:
#
# \begin{equation*}
# \hat{x_i} =  \frac {x_i - u}{d} \hspace{1cm} \forall i=1,2,3,4
# \end{equation*}

# %% [markdown]
# Il nuovo set di coordinate è $\hat{x_1},\hat{x_2},\hat{x_3},\hat{x_4}$.<br>
# Per fare questo calcolo uso <strong>torch.mul</strong> che realizza una moltiplicazione elemento-per-elemento tra i due operatori. Es.:
#
# \begin{equation}
# \begin{bmatrix}
# a_{11} & a_{12} \\
# a_{21} & a_{22} \\
# a_{31} & a_{32}
# \end{bmatrix}
# \begin{bmatrix}
# b_1 \\
# b_2
# \end{bmatrix}
# =
# \begin{bmatrix}
# a_{11}*b_1 & a_{12}*b_2 \\
# a_{21}*b_1 & a_{22}*b_2 \\
# a_{31}*b_1 & a_{32}*b_2
# \end{bmatrix}
# \end{equation}

# %%
X_norm = torch.mul((X-u),1/d)

# %% [markdown]
# Azzero il modello e ridefinisco l'ottimizzatore con un learning rate di 0.1

# %%
model2 = torch.nn.Linear(4,1) #ridefinisco il modello per azzerare i calcoli precedenti
optimizer = torch.optim.SGD(model2.parameters(), 0.1)

# %% [markdown]
# Copio il codice di prima per fare il training del modello, cambio solo l'ingresso, stavolta userò X_norm invece di X.

# %%
for itr in range(501):
    y_linmod = model2(X_norm)   #calcolo l'uscita con il modello corrente
    errore = torch.mean(torch.pow(y_samples-y_linmod,2)) #calcolo l'errore tra l'uscita desiderata e l'uscita corrente
    errore.backward()      #applico la funzione backward, le derivate parziali dell'errore vengono calcolate rispetto alle variabili per cui è definito required_grad=True
    optimizer.step()       #aggiornamento dei parametri da ottimizzare usando le derivate calcolate nel passo precedente
    optimizer.zero_grad()  #azzero i gradienti
    if ((itr==0) or (itr==100) or (itr==200) or (itr==300) or (itr==400) or (itr==500)) : #genera il grafico agli step fissati 
        ax = plt.figure(figsize = (12,8))
        plt.scatter(downsample_4_plot(asse_x,downsample_factor),
                    downsample_4_plot(y_samples, downsample_factor).numpy(),
                    label="dataset", c='g', s=200)
        plt.scatter(downsample_4_plot(asse_x,downsample_factor),
                    downsample_4_plot(y_linmod, downsample_factor).detach().numpy().reshape(1,-1),
                    c='r', label="linear model",s=10)
        plt.legend()
        plt.title('Dopo %d iterazioni - Errore= %1.2f' %(itr,errore))
        plt.show()

# %% [markdown]
# Sull'asse y abbiamo i valori di uscita, sull'asse x abbiamo l'ordinale del punto (e non la variabile di ingresso, poichè era impossibile riprodurre i 4 ingressi su grafico).<br>
# Per come sono fatti i dati, 4 assi ridotti ad un ordinale, sembra che ci siano 5 linee diverse in realta è un artefatto, dovuto al fatto he mi sto ostinando a rappresentare una cosa che non dovrei.<br>
# I valori desiderati li ho rappresentati con un marker molto spesso in modo che la posizione relativa tra le due curve sia ben visibile specialmente nel caso in cui sono vicine o sovrapposte.<br>
# Come si vede alla 300esima iterazione i due modelli lineare iniziano a sovrapporsi. Alla 500esima iterazione sono praticamente sovrapposti e l'errore è nullo (o molto basso).

# %% [markdown]
# Il training ci ha consegnato questi valori dei parametri ottimizzati:

# %%
model2.weight, model2.bias

# %% [markdown]
# I coefficienti angolari così ottenuti devono essere denormalizzati per tornare allo spazio $\mathbb{R}^4$ originale.<br>
# Per farlo divido ciascuna coordinata per il delta $d$ che avevo calcolato qualche step sopra.

# %% [markdown]
# Anche in questo caso faccio una moltiplicazione elemento-per-elemento con <strong>torch.mul</strong>

# %%
torch.mul(model2.weight,1/d)

# %% [markdown]
# Facciamo un confronto con i valori usati per generare il dataset:<br>
# m1 = 0.5 vs 0.4999<br>
# m2 = 25 vs 24.9961<br>
# m3 = 50 vs 49.9919<br>
# m4 = -0.66 vs -0.6599<br>
# Come si vede i valori trovati sono praticamente perfetti

# %% [markdown]
# Usando i parametri ottimizzati calcolo l'uscita e l'errore:

# %%
y_linmod = model2(X_norm)
errore = torch.mean(torch.pow(y_samples-y_linmod,2))
errore

# %% [markdown]
# Come atteso l'errore è molto basso.
